# %% [markdown]
# <a href="https://colab.research.google.com/github/komol21/flyrank-ml-internship/blob/main/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 1 - Research Question

# %% [markdown]
# ## 1. My Lane
#
# I selected the **Refresh / Content Opportunity Scoring** lane.
#
# I chose this lane because it helps identify which pages should be reviewed first. Since companies have thousands of pages, reviewing every page is not practical. A ranking system can help prioritize pages that may need attention.

# %% [markdown]
# ## 2. Research Question
#
# ### Research Question
#
# Which webpages should be reviewed first for content refresh?
#
# ### Decision
#
# Decide which pages should be reviewed before others.
#
# ### Unit of Analysis
#
# One webpage.
#
# ### Output
#
# A ranked list of webpages based on refresh priority.
#
# ### Action
#
# The SEO team will review the highest-ranked pages first.
#
# ### Cost of a Wrong Recommendation
#
# If the recommendation is wrong, the team may spend time reviewing the wrong pages while important pages are missed.

# %%
import pandas as pd

df = pd.read_csv("/content/content_refresh_anonymized.csv")

print("Rows, Columns:", df.shape)
print("Unique Clients:", df["client_id"].nunique())
print("Average CTR:", df["ctr"].mean())
# Out:
# Rows, Columns: (30000, 44)
# Unique Clients: 32
# Average CTR: 0.5107333333333334

# %%
print(df.columns)
# Out:
# Index(['content_id', 'client_id', 'search_volume', 'competition',
#        'competition_level', 'cpc', 'content_type', 'main_intent', 'word_count',
#        'char_count', 'provider_used', 'model_used', 'impressions_90d',
#        'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d',
#        'engaged_sessions_90d', 'ai_sessions_90d', 'scroll_events_90d',
#        'days_with_impressions', 'days_with_sessions', 'impressions_last_30d',
#        'clicks_last_30d', 'sessions_last_30d', 'impressions_prev_30d',
#        'clicks_prev_30d', 'sessions_prev_30d', 'content_age_days', 'age_tier',
#        'age_tier_order', 'days_since_last_update', 'freshness_tier',
#        'word_count_tier', 'char_count_tier', 'ctr', 'avg_position',
#        'engagement_rate', 'scroll_rate', 'ai_traffic_pct', 'impression_tier',
#        'position_tier', 'trend_direction', 'trend_pct'],
#       dtype='object')

# %% [markdown]
# ## 3. Quick Look at the Data
#
# The starter dataset contains thousands of webpage records from multiple clients.
#
# The dataset includes useful information such as impressions, clicks, sessions, CTR, and content age. These signals can help prioritize which pages should be reviewed first.

# %% [markdown]
# ## 4. Careful Words
#
# This notebook does not prove that updating a page will improve performance.
#
# It only identifies pages that may deserve review based on the available data.
